# %% [markdown]
# # **DG1AID - Foundations of Artificial Intelligence and Data Science**
#
# **Week 4 Lab sheet - example solutions**
#
# Created by Dr. Shereen Fouad, adapted by Matthew Bickley
#
# **In this session we will learn about two key machine learning libraries:**
# 1. Matplotlib
# 2. Pandas
#
# You have already been introduced to these last week when importing data (alongside numpy), but we will look more in-depth at them, including visualisation and customisation of the output. This session is a follow-on and revision material for last week, to ensure you understand how to import and manipulate data, and display it in a clear, visual way.
#
# Read through the notebook to see how Python commands are being implemeted. Then answer the exercise questions. Your answers should be added in code cells.

# %% [markdown]
# # **Matplotlib Crash Course**
#
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility. Matplotlib is open source and we can use it freely.
#
# The library is generally used as follows:
#
# 1. Call a plotting function with some data (e.g. plot()).
# 2. Call many functions to setup the properties of the plot (e.g. labels and colors).
# 3. Make the plot visible (e.g. show()).

# %% [markdown]
# **Import Matplotlib**
#
# Run the following code cell to import Matplotlib.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Line Plot**
#
# The example below creates a simple line plot from one-dimensional data.

# %%
# basic line plot
import numpy as np
myarray = np.array([1, 2, 3])
plt.plot(myarray)
plt.xlabel('some x axis')
plt.ylabel('some y axis')
plt.show()

# %% [markdown]
# **Multiple Points**
#
# You can plot as many points as you like, just make sure you have the same number of points in both axis.
#
# Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10):

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# **Plotting Without Line**
#
# To plot only the markers, you can use shortcut string notation parameter 'o', which means 'rings'.
#
# Draw two points in the diagram, one at position (1, 3) and one in position (8, 10):

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# **Plotting A Sine Wave Using Matplotlib And Numpy**
#
# *   Sine waves represent periodic oscillations.
# *   Sine waves have the shape of sine curve.
# *   The X-axis of the sine curve represents the time.
# *   The Y-axis of the sine curve represents the amplitude of the sine wave.

# %%
x_values = np.linspace(-3, 3, 100)
# np.linspace(start, stop, num) Return evenly spaced numbers over a specified interval.
# https://numpy.org/doc/stable/reference/generated/numpy.linspace.html
plt.figure()
plt.plot(x_values, np.sin(x_values), label="Sinusoid")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("Matplotlib example")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# **Scatter Plot**
#
# Below is a simple example of creating a scatter plot from two-dimensional data

# %%
# basic scatter plot
import matplotlib.pyplot as plt
import numpy
x = numpy.array([1, 2, 3])
y = numpy.array([2, 4, 6])
plt.scatter(x,y)
plt.xlabel('some x axis')
plt.ylabel('some y axis')
plt.show()

# %% [markdown]
# # **Exercise 1**
#
# **Exercise 1.1**
#
# Draw a line in a diagram from position (0,0) to position (5,100):

# %%
# ***************************************************
# INSERT YOUR CODE HERE
# ***************************************************

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 5])
ypoints = np.array([0, 100])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# **Exercise 1.2**
#
# Plot the following relu function using a line graph

# %%
def relu_numpy(x):
  return np.maximum(x, 0)

relu_numpy(np.array([-3, 3, 100]))
# Out:
# array([  0,   3, 100])

# %%
# ***************************************************
# INSERT YOUR CODE HERE
# ***************************************************

# %%
from matplotlib import pyplot as plt
import numpy as np
x_values = np.linspace(-3, 3, 100)

plt.figure()
plt.plot(x_values, relu_numpy(x_values), label="Relu")
plt.xlabel("x")
plt.title("relu funtion")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# **Exercise 1.3**
#
# Write a Python program to draw a scatter graph taking a random distribution in X and Y and plotted against each other.
#
# To solve this exercise you will need to use a builtin function called `randn` to create random numbers, which can be imported from the pylab library as follows:
#
# `from pylab import randn`
#
# The code snippet gives the output shown in the following screenshot:
#
# ![Picture1.jpg](data:image/jpeg;base64,...)

# %%
# ***************************************************
# INSERT YOUR CODE HERE
# ***************************************************

# %%
import matplotlib.pyplot as plt
from pylab import randn
X = randn(200)
Y = randn(200)
plt.scatter(X,Y, color='r')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# # **Pandas Crash Course**
# This Colab introduces DataFrames, which are the central data structure in the pandas API. This Colab is not a comprehensive DataFrames tutorial. Rather, this Colab provides a very quick introduction to the parts of DataFrames required to do the other Colab exercises in Machine Learning Crash Course.
#
# A DataFrame is similar to an in-memory spreadsheet. Like a spreadsheet:
#
# A DataFrame stores data in cells.
# A DataFrame has named columns (usually) and numbered rows.
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html

# %% [markdown]
# An initial step in machine learning and data analysis is the preparation of the data to be used in the analysis. In practice, the majority of the actual time spent on a machine learning  project is typically devoted to importing, cleaning, validating and transforming the dataset.
#
# This section will introduce pandas, an important third-party Python package for data analysis, as a tool for data preparation.

# %% [markdown]
# **Import pandas**
#
# Run the following code cell to import the pandas modules.

# %%
import pandas as pd

# %% [markdown]
# **Creating a DataFrame**
#
# The following code cell creates a simple DataFrame containing 10 cells organized as follows:
#
# *   5 rows
# *   2 columns, one named `temperature` and the other named `activity`
#
# The following code cell instantiates a `pd.DataFrame` class to generate a DataFrame. The class takes two arguments:
#
# The code
#
# *  The first argument provides the data to populate the 10 cells. The code cell calls np.array to generate the 5x2 NumPy array.
# *   The second argument identifies the names of the two columns.

# %%
# Create and populate a 5x2 NumPy array.
my_data = np.array([[0, 3], [10, 7], [20, 9], [30, 14], [40, 15]])

# Create a Python list that holds the names of the two columns.
my_column_names = ['temperature', 'activity']

# Create a DataFrame.
my_dataframe = pd.DataFrame(data=my_data, columns=my_column_names)

# Print the entire DataFrame
print(my_dataframe)
# Out:
#    temperature  activity
# 0            0         3
# 1           10         7
# 2           20         9
# 3           30        14
# 4           40        15

# %% [markdown]
# **Adding a new column to a DataFrame**
#
# You may add a new column to an existing pandas DataFrame just by assigning values to a new column name. For example, the following code creates a third column named adjusted in my_dataframe:

# %%
# Create a new column named adjusted.
my_dataframe["adjusted"] = my_dataframe["activity"] + 2

# Print the entire DataFrame
print(my_dataframe)
# Out:
#    temperature  activity  adjusted
# 0            0         3         5
# 1           10         7         9
# 2           20         9        11
# 3           30        14        16
# 4           40        15        17

# %% [markdown]
# **Specifying a subset of a DataFrame**
#
# Pandas provide multiples ways to isolate specific rows, columns, slices or cells in a DataFrame.

# %%
print("Rows #0, #1, and #2:")
# Return top 3 rows of the data frame
print(my_dataframe.head(3), '\n')

print("Row #2:")
print(my_dataframe.iloc[[2]], '\n')

print("Rows #1, #2, and #3:")
print(my_dataframe[1:4], '\n')

print("Column 'temperature':")
print(my_dataframe['temperature'])
# Out:
# Rows #0, #1, and #2:
#    temperature  activity  adjusted
# 0            0         3         5
# 1           10         7         9
# 2           20         9        11
#
# Row #2:
#    temperature  activity  adjusted
# 2           20         9        11
#
# Rows #1, #2, and #3:
#    temperature  activity  adjusted
# 1           10         7         9
# 2           20         9        11
# 3           30        14        16
#
# Column 'temperature':
# 0     0
# 1    10
# 2    20
# 3    30
# 4    40
# Name: temperature, dtype: int64

# %% [markdown]
# **Return a statistical summary of the dataframe**
#
# Next we'd like to know how values of each attributes are distributed. We can readily use the basic statistics (count, mean, min, max, quartiles) via the pandas `df.describe()` function. These can also be computed separately: df.count(), df.min(), df.max(), df.median(), df.quantile(q) Other statistics such as mode are also available separately, eg. df.mode()

# %%
my_dataframe.describe()
# Out:
#        temperature  activity  adjusted
# count     5.000000   5.00000   5.00000
# mean     20.000000   9.60000  11.60000
# std      15.811388   4.97996   4.97996
# min       0.000000   3.00000   5.00000
# 25%      10.000000   7.00000   9.00000
# 50%      20.000000   9.00000  11.00000
# 75%      30.000000  14.00000  16.00000
# max      40.000000  15.00000  17.00000

# %% [markdown]
# **Loading dataset into a pandas DataFrame**
#
# The dataset consists of a table - columns are attributes, rows are instances (individual observations). In order to do computations easily and efficiently and not to reinvent wheel we can use a suitable tool - pandas. So the first step is to obtain the dataset and load it into a DataFrame.
#
# Fortunately the dataset is already available via the scikit-learn package which gives it to us as a python data structure:

# %%
import pandas as pd

from sklearn.datasets import fetch_california_housing


dataset = fetch_california_housing()
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df['target'] = dataset.target

# Get a quick overview by printing the first 5 rows of the DataFrame:
print(df.head(5))

# Print the last 5 rows of the DataFrame:
print(df.tail())

# Return statistical description of the data in the DataFrame
df.describe()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# ...

# %% [markdown]
# The result of load_boston() is a map-like object with four components: ['target', 'data', 'DESCR', 'feature_names']:
#
# dataset['target'] - 1D numpy array of target attribute values
# dataset['data'] - 2D numpy array of attribute values
# dataset['feature_names'] - 1D numpy array of names of the attributes
# dataset['DESCR'] - text description of the dataset
# So it is easy to convert it to a pandas DataFrame.

# %% [markdown]
# **Read CSV Files and Load it into a pandas DataFrame**
#
# A simple way to store big data sets is to use CSV files (comma separated files).
# CSV files contains plain text and is a well know format that can be read by everyone including Pandas.
#
# In our examples we will be using a CSV file called 'data.csv'.
# *   Download the data.csv from Blackboard
# *   Save it on you local machine
# *   Upload the file in your colab drive as seen in the below photo. Or you can drag the file and drop it under files (on the left handside)
#
#
# ![Picture2.png](data:image/png;base64,...)

# %%
# Load the CSV into a DataFrame:
df = pd.read_csv("data.csv")

# %% [markdown]
# # **Exercise 2**
#
# **Exercise 2.1**
#
# Perform some data exploratory on data.csv as follows:
#
# 1.   use to_string() to print the entire DataFrame.
# 2.   Get a quick overview by printing the first 5 rows of the DataFrame:
# 3.   Print the last 5 rows of the DataFrame:
# 4.   Return statistical description of the data in the DataFrame

# %%
# ***************************************************
# INSERT YOUR CODE HERE
# ***************************************************

# %%
# Load the CSV into a DataFrame:
# df = pd.read_csv("data.csv")

# use to_string() to print the entire DataFrame.
print(df.to_string())

# Get a quick overview by printing the first 5 rows of the DataFrame:
print(df.head(5))

# Print the last 5 rows of the DataFrame:
print(df.tail(5))

# Return description of the data in the DataFrame
df.describe()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# **Exercise 2.2**
#
# Create a DataFrame, and Do the following:
#
# 1.   Create an 3x4 (3 rows x 4 columns) pandas DataFrame in which the columns are named Eleanor, Chidi, Tahani, and Jason.
# 2. Populate each of the 12 cells in the DataFrame with a random integer List item (use the numpy.random builtin function, more can be found [here](https://numpy.org/doc/1.16/reference/routines.random.html))
# 3. Return statistical description of the data in the DataFrame
# 4. Return top 2 rows of the data frame.

# %%
# ***************************************************
# INSERT YOUR CODE HERE
# ***************************************************

# %%
# Create a Python list that holds the names of the four columns.
my_column_names = ['Eleanor', 'Chidi', 'Tahani', 'Jason']

# Create a 3x4 numpy array, each cell populated with a random integer.
my_data = np.random.randint(low=0, high=101, size=(3, 4))

# Create a DataFrame.
df = pd.DataFrame(data=my_data, columns=my_column_names)
print(df.to_string())
# Return a statistical summary of the data frame
print(df.describe())

# Return top 3 rows of the data frame.
print(df.head(2))
# Out:
#    Eleanor  Chidi  Tahani  Jason
# 0       67     84      90     46
# 1       58     23      16     78
# 2       70     57      32     58
#          Eleanor      Chidi     Tahani      Jason
# count   3.000000   3.000000   3.000000   3.000000
# mean   65.000000  54.666667  46.000000  60.666667
# std     6.244998  30.566867  38.935845  16.165808
# min    58.000000  23.000000  16.000000  46.000000
# 25%    62.500000  40.000000  24.000000  52.000000
# 50%    67.000000  57.000000  32.000000  58.000000
# 75%    68.500000  70.500000  61.000000  68.000000
# max    70.000000  84.000000  90.000000  78.000000
#    Eleanor  Chidi  Tahani  Jason
# 0       67     84      90     46
# 1       58     23      16     78

# %% [markdown]
# **Exercise 2.3**
#
# Using the dataset data.csv, perform the following tasks:
#
#
#
# 1.   Calculate the total, mean, and maximum values for Duration, Pulse,Maxpulse, and Calories.
# 2.  Create a bar chart to visualize the total Calories burned for each 3.  Duration (grouped by duration).
# 3. Highlight the bar that represents the highest total calories burned.

# %%
# ***************************************************
# INSERT YOUR CODE HERE
# ***************************************************

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('data.csv')

# Calculate statistics
total_duration = data['Duration'].sum()
mean_duration = data['Duration'].mean()
max_duration = data['Duration'].max()

total_pulse = data['Pulse'].sum()
mean_pulse = data['Pulse'].mean()
max_pulse = data['Pulse'].max()

total_maxpulse = data['Maxpulse'].sum()
mean_maxpulse = data['Maxpulse'].mean()
max_maxpulse = data['Maxpulse'].max()

total_calories = data['Calories'].sum()
mean_calories = data['Calories'].mean()
max_calories = data['Calories'].max()

print(f'Total Duration: {total_duration}, Mean Duration: {mean_duration}, Max Duration: {max_duration}')
print(f'Total Pulse: {total_pulse}, Mean Pulse: {mean_pulse}, Max Pulse: {max_pulse}')
print(f'Total Maxpulse: {total_maxpulse}, Mean Maxpulse: {mean_maxpulse}, Max Maxpulse: {max_maxpulse}')
print(f'Total Calories: {total_calories}, Mean Calories: {mean_calories}, Max Calories: {max_calories}')

# Create a bar chart for total Calories grouped by Duration
calories_by_duration = data.groupby('Duration')['Calories'].sum().reset_index()

# Find the maximum calories
max_calories_row = calories_by_duration[calories_by_duration['Calories'] == calories_by_duration['Calories'].max()]

# Plotting
plt.figure(figsize=(10, 6))
bars = plt.bar(calories_by_duration['Duration'], calories_by_duration['Calories'], color='blue')

# Highlight the bar with the highest total calories
for bar in bars:
    if bar.get_x() == max_calories_row['Duration'].values[0] - 0.5:  # Adjusting for bar width
        bar.set_color('red')

# Add labels and title
plt.title('Total Calories Burned by Duration')
plt.xlabel('Duration (minutes)')
plt.ylabel('Total Calories')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show plot
plt.show()
# Out:
# Total Duration: 10790, Mean Duration: 63.84615384615385, Max Duration: 300
# Total Pulse: 18161, Mean Pulse: 107.46153846153847, Max Pulse: 159
# Total Maxpulse: 22654, Mean Maxpulse: 134.0473372781065, Max Maxpulse: 184
# Total Calories: 61629.600000000006, Mean Calories: 375.79024390243904, Max Calories: 1860.4
